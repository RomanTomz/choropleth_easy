# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import geopandas as gpd
import contextily as ctx
import geojson

# %%
df = pd.read_csv('datashine_QS701EW0010_OA.csv')

# %%
geo = gpd.read_file('/Users/admin/Jupyter/lchs_work/Maps/OA/england_oac_2011.shp')

# %%
geo.head()
# Out:
#                 oac_sub_gr              oac_group_           oac_super_  \
# 0  Student Communal Living  Students Around Campus        Cosmopolitans
# 1  Hard-Pressed Ethnic Mix     Migration and Churn  Hard-Pressed Living
# 2  Hard-Pressed Ethnic Mix     Migration and Churn  Hard-Pressed Living
# 3  Hard-Pressed Ethnic Mix     Migration and Churn  Hard-Pressed Living
# 4  Hard-Pressed Ethnic Mix     Migration and Churn  Hard-Pressed Living
#
#   oac_sub__1 oac_group  oac_supe_1  name  \
# 0        2a1        2a           2  None
# 1        8d2        8d           8  None
# 2        8d2        8d           8  None
# 3        8d2        8d           8  None
# 4        8d2        8d           8  None
#
#                                   label       code  \
# 0  E06000044E02003547E01017131E00086546  E00086546
# 1  E06000044E02003531E01017085E00086302  E00086302
# 2  E06000044E02003530E01017091E00086303  E00086303
# 3  E06000044E02003537E01017019E00085956  E00085956
# 4  E06000044E02003525E01017053E00086113  E00086113
#
#                                             geometry
# 0  POLYGON ((463839.333 99303.417, 463839.420 993...
# 1  POLYGON ((466653.780 104315.447, 466655.147 10...
# 2  POLYGON ((465615.000 103841.609, 465615.000 10...
# 3  POLYGON ((466056.679 100998.928, 466056.646 10...
# 4  POLYGON ((465056.606 106013.554, 465056.690 10...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#        index       OA Code Ward Name     LA Name  Region Name  QS701EW0010  \
# 0  E00116589  Hayling West    Havant  South East            5          224
# 1  E00116582  Hayling West    Havant  South East            3          229
# 2  E00116591  Hayling West    Havant  South East            6          206
# 3  E00116580  Hayling West    Havant  South East            4          176
# 4  E00116583  Hayling West    Havant  South East            9          218
#
#    QS701EW0001 (base)  OA Percentage
# 0                2.23            NaN
# 1                1.31            NaN
# 2                2.91            NaN
# 3                2.27            NaN
# 4                4.13            NaN

# %%
merged = geo.merge(df, left_on='code', right_on='index', how='inner')

# %%
merged.head()
# Out:
#                       oac_sub_gr                   oac_group_  \
# 0        Student Communal Living       Students Around Campus
# 1        Hard-Pressed Ethnic Mix          Migration and Churn
# 2     Challenged Transitionaries            White Communities
# 3  Deprived Blue-Collar Terraces  Challenged Terraced Workers
# 4  Deprived Blue-Collar Terraces  Challenged Terraced Workers
#
#                   oac_super_ oac_sub__1 oac_group  oac_supe_1  name  \
# 0              Cosmopolitans        2a1        2a           2  None
# 1        Hard-Pressed Living        8d2        8d           8  None
# 2  Constrained City Dwellers        7c1        7c           7  None
# 3        Hard-Pressed Living        8b1        8b           8  None
# 4        Hard-Pressed Living        8b1        8b           8  None
#
#                                   label       code  \
# 0  E06000044E02003547E01017131E00086546  E00086546
# 1  E06000044E02003537E01017019E00085956  E00085956
# 2  E06000044E02003540E01017093E00086327  E00086327
# 3  E06000044E02003540E01017096E00086324  E00086324
# 4  E06000044E02003540E01017096E00086325  E00086325
#
#                                             geometry      index    OA Code  \
# 0  POLYGON ((463839.333 99303.417, 463839.420 993...  E00086546  St Thomas
# 1  POLYGON ((466056.679 100998.928, 466056.646 10...  E00085956    Baffins
# 2  POLYGON ((467377.627 99642.684, 467418.221 996...  E00086327     Milton
# 3  POLYGON ((467243.421 99675.157, 467229.961 996...  E00086324     Milton
# 4  POLYGON ((466847.510 99630.553, 466854.920 996...  E00086325     Milton
#
#     Ward Name     LA Name  Region Name  QS701EW0010  QS701EW0001 (base)  \
# 0  Portsmouth  South East           12          561                2.14
# 1  Portsmouth  South East           17          391                4.35
# 2  Portsmouth  South East            9          216                4.17
# 3  Portsmouth  South East           12          209                5.74
# 4  Portsmouth  South East           15          224                6.70
#
#    OA Percentage
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
fig, ax = plt.subplots(1, figsize=(20,20))
ax.axis('off')
ax.set_title('Cycling to Work')

merged.plot(column='QS701EW0001 (base)', cmap='YlGn',
           linewidth=0.8, ax=ax, edgecolor='0')

plt.show()

fig.savefig('Cycling.png')

# %%
density = pd.read_csv('datashine_QS112EW0002_OA.csv')
density.reset_index(inplace=True)
density.head()
# Out:
#        index       OA Code Ward Name     LA Name  Region Name  QS112EW0002  \
# 0  E00116541  Hayling East    Havant  South East           73          472
# 1  E00116641    St Faith's    Havant  South East           41          320
# 2  E00116589  Hayling West    Havant  South East           33          306
# 3  E00116582  Hayling West    Havant  South East           37          314
# 4  E00116591  Hayling West    Havant  South East           53          294
#
#    QS112EW0001 (base)  OA Percentage
# 0               15.47            NaN
# 1               12.81            NaN
# 2               10.78            NaN
# 3               11.78            NaN
# 4               18.03            NaN

# %%
merged_density = geo.merge(density, right_on='index', left_on='code')

# %%
fig, ax = plt.subplots(1, figsize=(20,20))
ax.axis('off')
ax.set_title('Cycling to Work')

merged_density.plot(column='QS112EW0001 (base)', cmap='Blues_r',
           linewidth=0.8, ax=ax, edgecolor='0')

plt.show()

fig.savefig('density.png')

# %%
merged.columns
# Out:
# Index(['oac_sub_gr', 'oac_group_', 'oac_super_', 'oac_sub__1', 'oac_group',
#        'oac_supe_1', 'name', 'label', 'code', 'geometry', 'index', 'OA Code',
#        'Ward Name', 'LA Name', 'Region Name', 'QS701EW0010',
#        'QS701EW0001 (base)', 'OA Percentage'],
#       dtype='object')

# %%
merged = merged.to_crs(epsg=3857)

# %%
fig, ax = plt.subplots(1, figsize=(20,20))
ax.axis('off')
ax.set_title('Cycling to Work')

merged.plot(column='QS701EW0001 (base)', cmap='Oranges',
           linewidth=0.8, ax=ax, edgecolor='0', alpha=0.5)


ctx.add_basemap(ax,url='http://tile.stamen.com/toner/tileZ/tileX/tileY.png')

plt.show()

fig.savefig('Solent_TonerTile.png')
# Out:
# /Users/admin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   if __name__ == '__main__':
# /Users/admin/opt/anaconda3/lib/python3.7/site-packages/contextily/tile.py:268: FutureWarning: The url format using 'tileX', 'tileY', 'tileZ' as placeholders is deprecated. Please use '{x}', '{y}', '{z}' instead.
#   FutureWarning,

# %%
geo = gpd.read_file('/Users/admin/Jupyter/lchs_work/Maps/Wards/Wards_(December_2017)_Boundaries_in_the_UK_(WGS84).shp')

# %%
geo

# %%
df = pd.read_csv('bulk.csv')
df.head()

# %%
merged = df.merge(geo, left_on='geography code', right_on='wd17cd', how='inner')
merged
